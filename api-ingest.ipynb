# %% [markdown]
# Ingesting Data via API

# %%
import requests
import os
from dotenv import load_dotenv
import pprint
import pandas as pd

load_dotenv()
url = 'https://api-v3.mbta.com/'
api_key = os.getenv("API_KEY")
headers = {'X-API-Key': api_key}
response = requests.get(f'{url}routes?filter[type]=0,1', headers=headers)

if response.status_code == 200:
    data = response.json()
    # for route in data['data']:
    #     print(route['attributes']['long_name'], route['attributes']['direction_names'])
    print(f"Total routes: {len(data['data'])}")
    df = pd.json_normalize(data['data'])
    df.to_csv('mbta_routes.csv', index=False)
    print(df)
else:
    print(f'Error: {response.status_code}')
# Out:
# Total routes: 8
#          id   type attributes.color attributes.description  \
# 0       Red  route           DA291C          Rapid Transit
# 1  Mattapan  route           DA291C          Rapid Transit
# 2    Orange  route           ED8B00          Rapid Transit
# 3   Green-B  route           00843D          Rapid Transit
# 4   Green-C  route           00843D          Rapid Transit
# 5   Green-D  route           00843D          Rapid Transit
# 6   Green-E  route           00843D          Rapid Transit
# 7      Blue  route           003DA5          Rapid Transit
#
#        attributes.direction_destinations attributes.direction_names  \
# 0           [Ashmont/Braintree, Alewife]             [South, North]
# 1                    [Mattapan, Ashmont]        [Outbound, Inbound]
# 2              [Forest Hills, Oak Grove]             [South, North]
# 3    [Boston College, Government Center]               [West, East]
# 4  [Cleveland Circle, Government Center]               [West, East]
# 5              [Riverside, Union Square]               [West, East]
# 6          [Heath Street, Medford/Tufts]               [West, East]
# 7                  [Bowdoin, Wonderland]               [West, East]
#
#   attributes.fare_class  attributes.listed_route attributes.long_name  \
# 0         Rapid Transit                     True             Red Line
# 1         Rapid Transit                     True        Mattapan Line
# 2         Rapid Transit                     True          Orange Line
# 3         Rapid Transit                     True         Green Line B
# 4         Rapid Transit                     True         Green Line C
# 5         Rapid Transit                     True         Green Line D
# 6         Rapid Transit                     True         Green Line E
# 7         Rapid Transit                     True            Blue Line
#
#   attributes.short_name  attributes.sort_order attributes.text_color  \
# 0                                        10010                FFFFFF
# 1                                        10011                FFFFFF
# 2                                        10020                FFFFFF
# 3                     B                  10032                FFFFFF
# 4                     C                  10033                FFFFFF
# 5                     D                  10034                FFFFFF
# 6                     E                  10035                FFFFFF
# 7                                        10040                FFFFFF
#
#    attributes.type        links.self relationships.agency.data.id  \
# 0                1       /routes/Red                            1
# 1                0  /routes/Mattapan                            1
# 2                1    /routes/Orange                            1
# 3                0   /routes/Green-B                            1
# 4                0   /routes/Green-C                            1
# 5                0   /routes/Green-D                            1
# 6                0   /routes/Green-E                            1
# 7                1      /routes/Blue                            1
#
#   relationships.agency.data.type relationships.line.data.id  \
# 0                         agency                   line-Red
# 1                         agency              line-Mattapan
# 2                         agency                line-Orange
# 3                         agency                 line-Green
# 4                         agency                 line-Green
# 5                         agency                 line-Green
# 6                         agency                 line-Green
# 7                         agency                  line-Blue
#
#   relationships.line.data.type
# 0                         line
# 1                         line
# 2                         line
# 3                         line
# 4                         line
# 5                         line
# 6                         line
# 7                         line
